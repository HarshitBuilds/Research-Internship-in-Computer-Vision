# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/untrained-dataset/Untrained/cropped_1175_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1271_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1067_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1403_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1429_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1231_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1237_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1428_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1169_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1035_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1145_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1438_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1403_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1375_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1211_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1253_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1247_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1177_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1141_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1391_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1213_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1207_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1393_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1041_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1233_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1301_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1097_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1421_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1047_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1385_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1261_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1395_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1059_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1029_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1065_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1331_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1383_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1121_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1155_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1275_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1091_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1153_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1251_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1101_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1440_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1225_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1239_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1123_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1421_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1430_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1213_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1231_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1305_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1445_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1319_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1243_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1127_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1361_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1163_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1353_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1444_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1419_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1317_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1243_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1327_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1023_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1409_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1189_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1391_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1379_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1285_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1341_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1418_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1301_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1133_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1177_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1313_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1211_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1201_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1219_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1133_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1237_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1109_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1387_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1450_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1221_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1327_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1209_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1219_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1363_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1439_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1149_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1167_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1145_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1371_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1047_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1023_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1151_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1113_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1225_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1439_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1035_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1049_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1179_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1347_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1033_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1444_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1129_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1213_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1129_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1059_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1045_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1155_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1073_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1279_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1319_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1293_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1355_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1353_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1199_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1415_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1395_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1073_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1435_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1085_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1287_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1251_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1447_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1113_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1369_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1155_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1426_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1011_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1383_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1119_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1069_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1215_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1259_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1181_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1305_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1377_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1093_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1125_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1440_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1361_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1303_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1339_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1438_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1285_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1063_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1223_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1165_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1307_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1031_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1299_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1255_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1037_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1369_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1083_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1383_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1418_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1433_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1135_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1379_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1065_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1426_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1191_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1229_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1173_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1428_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1167_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1289_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1229_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1085_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1331_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1401_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1291_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1422_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1055_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1189_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1309_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1283_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1351_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1307_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1299_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1107_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1197_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1031_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1071_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1420_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1403_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1065_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1357_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1401_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1011_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1067_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1269_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1371_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1437_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1127_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1271_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1249_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1279_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1273_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1167_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1377_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1428_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1317_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1295_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1321_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1271_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1432_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1191_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1233_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1023_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1123_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1013_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1151_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1099_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1365_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1235_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1177_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1241_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1417_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1418_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1363_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1411_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1207_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1105_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1049_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1241_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1429_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1163_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1239_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1285_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1201_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1197_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1069_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1043_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1147_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1133_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1189_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1095_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1135_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1391_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1219_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1213_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1107_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1171_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1427_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1279_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1323_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1261_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1033_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1183_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1203_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1265_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1347_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1297_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1309_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1103_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1420_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1169_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1125_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1426_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1025_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1401_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1428_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1229_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1153_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1143_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1135_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1179_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1411_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1131_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1429_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1121_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1099_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1449_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1299_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1235_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1017_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1413_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1289_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1429_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1225_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1403_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1365_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1249_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1309_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1037_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1450_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1015_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1323_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1359_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1448_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1127_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1021_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1029_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1447_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1405_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1427_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1197_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1411_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1397_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1418_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1385_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1341_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1023_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1359_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1119_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1319_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1419_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1351_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1075_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1369_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1047_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1351_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1083_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1157_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1205_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1051_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1177_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1243_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1171_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1361_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1379_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1217_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1085_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1167_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1255_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1021_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1121_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1287_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1283_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1251_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1025_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1422_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1069_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1103_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1167_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1185_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1191_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1235_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1209_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1293_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1287_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1129_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1448_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1031_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1327_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1349_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1355_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1351_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1303_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1231_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1049_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1139_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1423_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1444_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1139_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1309_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1069_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1167_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1127_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1345_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1245_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1157_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1231_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1221_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1251_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1253_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1309_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1381_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1263_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1193_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1123_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1241_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1055_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1191_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1047_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1203_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1441_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1201_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1269_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1233_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1335_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1265_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1444_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1347_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1089_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1045_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1009_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1093_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1207_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1440_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1089_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1127_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1213_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1105_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1113_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1097_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1275_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1269_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1415_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1357_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1253_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1357_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1427_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1261_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1419_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1163_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1277_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1433_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1015_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1435_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1089_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1079_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1057_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1021_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1413_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1093_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1071_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1321_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1211_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1405_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1093_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1427_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1143_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1415_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1083_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1083_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1319_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1367_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1363_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1381_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1181_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1297_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1359_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1121_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1063_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1441_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1279_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1159_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1273_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1437_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1251_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1167_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1205_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1249_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1425_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1015_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1393_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1169_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1387_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1341_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1181_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1435_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1137_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1279_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1425_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1321_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1373_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1253_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1395_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1073_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1179_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1099_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1075_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1237_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1247_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1157_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1407_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1219_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1446_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1303_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1405_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1079_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1259_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1195_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1434_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1203_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1418_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1424_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1333_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1205_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1259_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1373_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1137_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1175_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1212_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1395_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1387_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1023_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1363_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1067_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1161_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1447_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1169_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1422_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1305_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1445_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1029_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1373_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1418_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1399_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1187_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1077_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1139_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1241_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1212_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1333_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1031_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1415_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1407_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1405_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1343_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1073_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1447_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1277_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1361_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1027_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1041_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1151_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1221_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1361_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1229_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1099_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1443_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1117_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1255_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1021_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1071_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1212_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1313_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1299_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1385_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1173_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1217_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1127_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1115_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1421_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1191_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1365_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1445_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1081_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1153_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1283_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1409_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1347_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1165_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1337_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1039_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1333_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1227_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1333_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1393_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1013_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1417_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1446_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1261_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1297_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1287_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1413_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1279_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1343_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1119_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1333_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1219_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1315_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1357_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1435_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1355_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1217_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1021_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1313_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1347_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1409_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1057_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1017_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1447_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1367_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1425_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1375_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1259_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1161_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1329_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1247_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1189_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1418_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1299_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1391_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1151_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1187_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1295_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1295_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1049_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1075_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1283_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1015_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1446_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1321_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1195_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1081_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1405_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1401_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1115_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1289_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1369_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1085_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1083_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1043_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1059_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1446_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1129_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1359_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1233_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1019_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1035_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1311_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1439_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1379_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1241_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1081_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1097_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1197_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1191_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1011_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1171_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1165_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1021_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1057_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1301_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1281_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1071_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1125_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1097_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1345_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1095_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1155_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1419_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1383_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1045_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1033_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1432_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1245_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1426_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1105_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1151_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1009_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1077_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1391_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1017_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1091_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1111_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1442_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1431_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1267_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1157_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1111_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1059_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1159_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1213_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1027_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1315_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1387_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1323_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1095_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1049_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1113_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1111_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1443_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1263_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1343_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1131_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1123_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1047_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1363_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1313_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1239_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1103_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1025_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1187_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1428_11_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1379_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1087_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1439_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1415_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1212_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1341_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1422_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1201_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1207_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1443_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1329_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1169_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1099_11_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1415_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1403_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1275_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1263_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1379_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1065_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1439_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1229_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1339_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1151_01_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1307_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1117_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1197_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1113_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1025_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1239_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1355_01_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1423_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1349_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1229_10_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1247_10_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1061_10_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1365_00_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1409_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1347_10_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1401_00_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1329_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1321_01_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1442_00_10.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1243_00_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1359_11_01.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1441_01_11.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1131_11_00.tif
# /kaggle/input/untrained-dataset/Untrained/cropped_1423_00_00.tif
# ...
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1048_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1020_00_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1330_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1008_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1352_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1010_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1324_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1007_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1016_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1010_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1008_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1342_00_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1062_10_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1332_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1374_10_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1332_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1338_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1002_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1330_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1336_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1016_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1322_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1006_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1320_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1370_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1016_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1414_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1018_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1338_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1322_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1010_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1324_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1016_00_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1334_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1005_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1003_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1007_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1394_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1334_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1008_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1050_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1348_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1016_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1328_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1332_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1332_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1338_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1338_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1374_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1362_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1012_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1336_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1340_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1007_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1012_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1416_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1008_01_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1366_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1328_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1344_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1003_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/training/cropped_1004_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1338_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1338_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1342_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1322_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1012_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1328_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1016_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1008_11_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1410_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1334_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1346_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1004_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1376_10_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1372_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1316_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1010_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1378_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1018_00_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1314_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1324_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1334_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1012_01_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1316_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1314_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1342_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1318_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1388_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1336_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1066_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1014_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1388_00_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1010_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1326_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1006_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1330_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1360_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1012_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1007_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1386_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1416_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1330_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1340_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1368_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1364_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1060_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1326_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1376_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1320_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1376_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1342_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1010_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1390_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1342_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1326_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1316_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1330_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1014_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1334_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1384_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1318_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1014_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1382_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1314_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1340_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1016_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1344_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1018_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1320_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1374_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1344_00_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1412_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1334_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1007_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1008_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1340_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1006_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1022_00_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1320_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1392_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1012_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1008_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1332_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1336_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1336_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1005_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1318_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1014_01_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1014_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1020_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1372_10_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1012_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1010_01_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1328_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1340_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1326_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1005_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1336_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1048_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1020_00_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1330_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1008_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1352_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1010_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1324_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1007_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1016_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1010_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1008_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1342_00_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1062_10_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1332_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1374_10_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1332_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1338_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1002_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1330_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1336_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1016_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1322_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1006_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1320_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1370_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1016_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1414_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1018_10_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1338_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1322_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1010_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1324_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1016_00_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1334_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1005_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1003_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1007_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1394_00_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1334_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1008_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1050_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1348_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1016_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1328_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1332_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1332_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1338_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1338_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1374_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1362_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1012_11_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1336_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1340_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1007_10_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1012_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1416_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1008_01_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1366_01_00.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1328_01_11.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1344_01_10.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1003_11_01.tif
# /kaggle/input/largevoids/big_voids_samples/mask/cropped_1004_11_10.tif

# %%
import pandas as pd
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torch.utils.data import random_split
import torch
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
import cv2
from sklearn.model_selection import train_test_split
import os
from PIL import Image
from tqdm import tqdm
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset,ConcatDataset

# %%
#loading the data

class CustomDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx])

        image = Image.open(img_path).convert("L")  # Convert image to grayscale
        mask = Image.open(mask_path).convert("L")  # Convert mask to grayscale

        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask

# Define transformations
transform = tt.Compose([
    tt.ToTensor()
])

# Create dataset and dataloader
image_dir = r'/kaggle/input/data-512/512x512/Training'
mask_dir = r'/kaggle/input/data-512/512x512/Mask'
dataset = CustomDataset(image_dir, mask_dir, transform)

# Define the split ratio
train_size = int(0.8 * len(dataset)) # 90% for training
aug_size = int(0 * len(dataset))  
val_size = len(dataset) - train_size - aug_size  # 10% for validation

seed = 42
torch.manual_seed(seed)
train_dataset,augmentation_dataset, val_dataset = random_split(dataset, [train_size,aug_size ,val_size])

aug_dir_training = r'/kaggle/input/largevoids/big_voids_samples/training'
aug_dir_mask = r'/kaggle/input/largevoids/big_voids_samples/mask'
aug_dataset = CustomDataset(aug_dir_training, aug_dir_mask, transform)

# %%
len(aug_dataset)
# Out:
# 159

# %%
train_transform = tt.Compose([tt.RandomVerticalFlip(),
                         tt.RandomHorizontalFlip(),
                         #tt.RandomResizedCrop(256, scale=(0.5,0.9), ratio=(1, 1)),
                         tt.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1)
                        ])

# %%
augmented_samples = []

# Apply transformations to each sample in train_ds
for image, mask in aug_dataset:
    augmented_samples_for_image = []
    for _ in range(9):  # Define the number of augmented samples per original sample
        seed = torch.seed()  # Seed for reproducibility
        torch.manual_seed(seed)
        augmented_image = train_transform(image)

        torch.manual_seed(seed)
        augmented_mask = train_transform(mask)

        augmented_samples_for_image.append((augmented_image, augmented_mask))

    augmented_samples.extend(augmented_samples_for_image)
    # Convert augmented samples to tensors
augmented_images, augmented_masks = zip(*augmented_samples)
augmented_images = torch.stack(augmented_images)  # Convert list of tensors to a single tensor
augmented_masks = torch.stack(augmented_masks)  # Convert list of labels to a tensor
    # Create a TensorDataset
augmented_train_ds = TensorDataset(augmented_images, augmented_masks)

# %%
train_dataset = ConcatDataset([train_dataset, augmented_train_ds])

# %%
len(train_dataset)
# Out:
# 4144

# %%
batch_size = 1
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

# %%
class Unet(nn.Module):
    def __init__(self):
        super(Unet, self).__init__()
        def CBR(in_channels, out_channels):
          return nn.Sequential(
              nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1),
              nn.BatchNorm2d(out_channels),
              nn.ReLU(),
              nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1),
              nn.BatchNorm2d(out_channels),
              nn.ReLU()
          )

        #Downsampling the data
        self.encoder1 = CBR(1, 64) #2048x2048x64
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) #1024x1024x64
        self.encoder2 = CBR(64, 128) #1054x1054x128
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) #512x512x128
        self.encoder3 = CBR(128, 256) #512x512x256
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) #256x256x512
        self.encoder4 = CBR(256, 512) #256x256x512
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2) #128x128x512

        #Bottleneck containing 1024 channels.
        self.bottleneck = CBR(512, 1024) #128x128x1024

        #Upsampling the data
        self.upconv4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2) #256x256x512
        self.decoder4 = CBR(1024, 512) #256x256x512
        self.upconv3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.decoder3 = CBR(512, 256)
        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.decoder2 = CBR(256, 128)
        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.decoder1 = CBR(128, 64)

        self.conv_last = nn.Conv2d(64, 1, kernel_size=1)

    #Forward pass of the model
    def forward(self,x):
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(self.pool1(enc1))
        enc3 = self.encoder3(self.pool2(enc2))
        enc4 = self.encoder4(self.pool3(enc3))

        bottleneck = self.bottleneck(self.pool4(enc4))

        dec4 = self.upconv4(bottleneck)
        dec4 = torch.cat((dec4, enc4), dim=1)
        dec4 = self.decoder4(dec4)

        dec3 = self.upconv3(dec4)
        dec3 = torch.cat((dec3, enc3), dim=1)
        dec3 = self.decoder3(dec3)

        dec2 = self.upconv2(dec3)
        dec2 = torch.cat((dec2, enc2), dim=1)
        dec2 = self.decoder2(dec2)

        dec1 = self.upconv1(dec2)
        dec1 = torch.cat((dec1, enc1), dim=1)
        dec1 = self.decoder1(dec1)

        return torch.sigmoid(self.conv_last(dec1))

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, predicted, target):
        intersection = torch.sum(predicted * target)
        union = torch.sum(predicted) + torch.sum(target)
        dice = (2. * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice

# %%
model = Unet()

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0):
        self.patience = patience
        self.delta = delta
        self.best_score = None
        self.early_stop = False
        self.counter = 0
        self.best_model_state = None

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.best_model_state = model.state_dict()
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.best_model_state = model.state_dict()
            self.counter = 0

    def load_best_model(self, model):
        model.load_state_dict(self.best_model_state)

# %%
def train_model(model, train_loader, val_loader, epochs=10, accumulation_steps=6):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = DiceLoss()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    early_stopping = EarlyStopping(patience=5, delta=0.01)
    model.to(device)

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0

        # Initialize accumulation variables
        optimizer.zero_grad()

        progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f"Epoch {epoch+1}/{epochs}")

        for i, (image, mask) in progress_bar:
            image, mask = image.to(device), mask.to(device)
            output = model(image)
            loss = criterion(output, mask)
            loss.backward()

            if (i + 1) % accumulation_steps == 0:  # gradient accumulation
                optimizer.step()  # Update weights
                optimizer.zero_grad()  # Clear the gradients for the next accumulation

            train_loss += loss.item()

        # If there are remaining gradients to be updated
        if (i + 1) % accumulation_steps != 0:
            optimizer.step()
            optimizer.zero_grad()

        train_loss = train_loss / len(train_loader)

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for image, mask in val_loader:
                image, mask = image.to(device), mask.to(device)
                output = model(image)
                loss = criterion(output, mask)
                val_loss += loss.item()

        val_loss = val_loss / len(val_loader)

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
        
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break

    early_stopping.load_best_model(model)

# %%
train_model(model, train_loader,val_loader,epochs = 15)
# Out:
# Epoch 1/15: 100%|██████████| 4144/4144 [16:37<00:00,  4.15it/s]
# Epoch 1/15, Train Loss: 0.7008, Val Loss: 0.7040
# Epoch 2/15: 100%|██████████| 4144/4144 [16:35<00:00,  4.16it/s]
# Epoch 2/15, Train Loss: 0.5561, Val Loss: 0.6848
# Epoch 3/15: 100%|██████████| 4144/4144 [16:32<00:00,  4.18it/s]
# Epoch 3/15, Train Loss: 0.3432, Val Loss: 0.0214
# Epoch 4/15: 100%|██████████| 4144/4144 [16:34<00:00,  4.17it/s]
# Epoch 4/15, Train Loss: 0.1445, Val Loss: 0.0234
# Epoch 5/15: 100%|██████████| 4144/4144 [16:33<00:00,  4.17it/s]
# Epoch 5/15, Train Loss: 0.1129, Val Loss: 0.0211
# Epoch 6/15: 100%|██████████| 4144/4144 [16:34<00:00,  4.17it/s]
# Epoch 6/15, Train Loss: 0.0766, Val Loss: 0.0136
# Epoch 7/15: 100%|██████████| 4144/4144 [16:37<00:00,  4.15it/s]
# Epoch 7/15, Train Loss: 0.0682, Val Loss: 0.0170
# Epoch 8/15: 100%|██████████| 4144/4144 [16:48<00:00,  4.11it/s]
# Epoch 8/15, Train Loss: 0.0675, Val Loss: 0.0203
# Early stopping

# %%
torch.save(model.state_dict(), 'UNET_512_DICE_largevoids.pth')
